# %% [markdown]
# ### Tokenization

# %%
corpus = """This is a sample corpus.
It is supposed to be a paragraph."""

# %%
print(corpus)
# Out:
# This is a sample corpus.
# It is supposed to be a paragraph.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/mac/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(corpus)
# Out:
# ['This is a sample corpus.', 'It is supposed to be a paragraph.']

# %%
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['This',
#  'is',
#  'a',
#  'sample',
#  'corpus',
#  '.',
#  'It',
#  'is',
#  'supposed',
#  'to',
#  'be',
#  'a',
#  'paragraph',
#  '.']
